# %% [markdown]
# Data preperation and basic exploration:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Masters Computer\Desktop\VScode_For_ Python\internship\project1\Data\synthetic_heart_disease_dataset.csv", keep_default_na=False)

# %%
print (df.shape,"\n")
df.info()
# Out:
# (50000, 21)
#
# Index(['Age', 'Gender', 'Weight', 'Height', 'BMI', 'Smoking', 'Alcohol_Intake',
#        'Physical_Activity', 'Diet', 'Stress_Level', 'Hypertension', 'Diabetes',
#        'Hyperlipidemia', 'Family_History', 'Previous_Heart_Attack',
#        'Systolic_BP', 'Diastolic_BP', 'Heart_Rate', 'Blood_Sugar_Fasting',
#        'Cholesterol_Total', 'Heart_Disease'],
#       dtype='str')
#
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    50000 non-null  int64
#  1   Gender                 50000 non-null  str
#  2   Weight                 50000 non-null  int64
#  3   Height                 50000 non-null  int64
#  4   BMI                    50000 non-null  float64
#  5   Smoking                50000 non-null  str
#  6   Alcohol_Intake         50000 non-null  str
# ...

# %% [markdown]
# Alcohol_Intake         29891 non-null  it is actually all non null,
#  but since the categories of using alchol is "'high' 'moderate' 'low' 'none'" ,
#   it is counting the 'none' word as null while it points to the amount of consumbtion.
#
#   PS: we have to deal with it becuase it seems problamatic.
#
#   we can see in the following that althought 'none' is supposed to be a category it is not listed in value counts !
#
#   PS: since my CSV contains "none" as a valid category, pandas may convert it to NaN.
#    So, we deal with it when loading data by stopping pandas's auto-converting via using "keep_default_na=False" .

# %% [markdown]
# Alcohol_Intake = None represents patients who do not consume alcohol and is therefore treated as a valid category rather than a missing value.

# %%
df['Alcohol_Intake'].value_counts()
# Out:
# Alcohol_Intake
# None        20109
# Low         14913
# Moderate     9895
# High         5083
# Name: count, dtype: int64

# %% [markdown]
# Checking for duplicates and nulls :

# %%
print("Null count:\n",df.isnull().sum())

print("\nDuplicates count:", df.duplicated().sum())
# Out:
# Null count:
#  Age                      0
# Gender                   0
# Weight                   0
# Height                   0
# BMI                      0
# Smoking                  0
# Alcohol_Intake           0
# Physical_Activity        0
# Diet                     0
# Stress_Level             0
# Hypertension             0
# Diabetes                 0
# Hyperlipidemia           0
# Family_History           0
# Previous_Heart_Attack    0
# Systolic_BP              0
# Diastolic_BP             0
# Heart_Rate               0
# Blood_Sugar_Fasting      0
# Cholesterol_Total        0
# Heart_Disease            0
# dtype: int64
#
# Duplicates count: 0

# %%
print(df.columns,"\n")
# Out:
# Index(['Age', 'Gender', 'Weight', 'Height', 'BMI', 'Smoking', 'Alcohol_Intake',
#        'Physical_Activity', 'Diet', 'Stress_Level', 'Hypertension', 'Diabetes',
#        'Hyperlipidemia', 'Family_History', 'Previous_Heart_Attack',
#        'Systolic_BP', 'Diastolic_BP', 'Heart_Rate', 'Blood_Sugar_Fasting',
#        'Cholesterol_Total', 'Heart_Disease'],
#       dtype='str')

# %%
# seperate categorical & numerical (list the 'name only' of the columns of each type )
# used later for (Column transformer)
categorical_cols = df.select_dtypes(include=['str']).columns.tolist()

numerical_cols = df.select_dtypes(include=['int64','float64']).columns.tolist()

print("categorical columns name: ")
print(categorical_cols)

print("\nnumerical columns name: ")
print(numerical_cols)
# Out:
# categorical columns name:
# ['Gender', 'Smoking', 'Alcohol_Intake', 'Physical_Activity', 'Diet', 'Stress_Level']
#
# numerical columns name:
# ['Age', 'Weight', 'Height', 'BMI', 'Hypertension', 'Diabetes', 'Hyperlipidemia', 'Family_History', 'Previous_Heart_Attack', 'Systolic_BP', 'Diastolic_BP', 'Heart_Rate', 'Blood_Sugar_Fasting', 'Cholesterol_Total', 'Heart_Disease']

# %%
#describtion of numerical columns
df[numerical_cols].describe()
# Out:
#                Age        Weight        Height           BMI  Hypertension  \
# count  50000.00000  50000.000000  50000.000000  50000.000000  50000.000000
# mean      54.46406     84.547520    174.460000     28.984284      0.299620
# std       14.43809     20.213257     14.420379      6.367494      0.458096
# min       30.00000     50.000000    150.000000     18.000000      0.000000
# 25%       42.00000     67.000000    162.000000     23.500000      0.000000
# 50%       54.00000     85.000000    174.000000     29.000000      0.000000
# 75%       67.00000    102.000000    187.000000     34.500000      1.000000
# max       79.00000    119.000000    199.000000     40.000000      1.000000
#
#            Diabetes  Hyperlipidemia  Family_History  Previous_Heart_Attack  \
# count  50000.000000    50000.000000    50000.000000           50000.000000
# mean       0.199260        0.251660        0.400500               0.099280
# ...

# %%
#describtion (value counts) of categorcial columns
for val in categorical_cols:
    
    print("value counts: ")
    print (df[val].value_counts(),"\n")
# Out:
# value counts:
# Gender
# Female    25110
# Male      24890
# Name: count, dtype: int64
#
# value counts:
# Smoking
# Never      30160
# Current     9965
# Former      9875
# Name: count, dtype: int64
#
# value counts:
# Alcohol_Intake
# None        20109
# Low         14913
# Moderate     9895
# High         5083
# Name: count, dtype: int64
#
# value counts:
# Physical_Activity
# Moderate     24976
# Sedentary    15077
# Active        9947
# Name: count, dtype: int64
#
# value counts:
# Diet
# Average      25169
# Healthy      14975
# Unhealthy     9856
# Name: count, dtype: int64
#
# value counts:
# Stress_Level
# Medium    20133
# Low       19941
# High       9926
# Name: count, dtype: int64

# %%
#target column
df['Heart_Disease'].value_counts()
# Out:
# Heart_Disease
# 0    26827
# 1    23173
# Name: count, dtype: int64
