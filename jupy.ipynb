# %%
! pip install pandas
# Out:
# ...
#   Using cached numpy-2.5.1-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.8 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.8 MB 5.0 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.8 MB 4.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.8 MB 3.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.8 MB 3.3 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 3.6 MB/s eta 0:00:02
# ...

# %% [markdown]
# all libraries installed succesfully

# %%
print("hello")
# Out:
# hello
